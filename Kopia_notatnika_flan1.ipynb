# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
tokenizer = T5Tokenizer.from_pretrained("google/flan-t5-large")

# %%
from transformers import T5Tokenizer, T5ForConditionalGeneration
# !pip install sentencepiece
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
model = T5ForConditionalGeneration.from_pretrained("google/flan-t5-large").to("cuda")

# %%
def generate(input_text):
  input_ids = tokenizer(input_text, return_tensors="pt").input_ids.to("cuda")
  output = model.generate(input_ids, max_length=100)
  return tokenizer.decode(output[0], skip_special_tokens=True)

# %%
input_text = " W rozmowie z Radiem Elka 17-latek przyznał, że "od początkowych etapów edukacji" najważniejsza dla niego była różnorodność. - Przede wszystkim mam osiągnięcia z dziedziny ekonomii, z finansów. Różne konkursy - czy to regionalne, krajowe, czy nawet międzynarodowe się pojawiły. Głównie w dziedzinie finansów, np. w zakładaniu swojej własnej firmy, start-upów, takie symulacje. Mam również osiągnięcia w fizyce, szczególnie w astronomii. To jest właśnie to, co w liceum robię tak naprawdę. (...) Pojawiły się również humanistyczne osiągnięcia, na przykład debaty. Uczestniczyłem w leszczyńskich debatach, w wojewódzkich także. Trudno byłoby wymienić wszystkie [osiągnięcia - red.]. Pojawiła się matematyka czy też języki, bo od początku interesowałem się językami, językiem angielskim i również językiem niemieckim - wymieniał nastolatek."
generate(input_text)
# Out:
#   File "<ipython-input-9-6af2e7e56fbd>", line 1
#     input_text = " W rozmowie z Radiem Elka 17-latek przyznał, że "od początkowych etapów edukacji" najważniejsza dla niego była różnorodność. - Przede wszystkim mam osiągnięcia z dziedziny ekonomii, z finansów. Różne konkursy - czy to regionalne, krajowe, czy nawet międzynarodowe się pojawiły. Głównie w dziedzinie finansów, np. w zakładaniu swojej własnej firmy, start-upów, takie symulacje. Mam również osiągnięcia w fizyce, szczególnie w astronomii. To jest właśnie to, co w liceum robię tak naprawdę. (...) Pojawiły się również humanistyczne osiągnięcia, na przykład debaty. Uczestniczyłem w leszczyńskich debatach, w wojewódzkich także. Trudno byłoby wymienić wszystkie [osiągnięcia - red.]. Pojawiła się matematyka czy też języki, bo od początku interesowałem się językami, językiem angielskim i również językiem niemieckim - wymieniał nastolatek."
#                                                                    ^
# ...

# %%
input_text = "Personel, sądząc iż Kowalski jest kontrolerem PIH - u, momentalnie zmienił swój stosunek do klientów, bohater znalazł w swojej gazecie banknot pięćsetzłotowy. Początkowo zaskoczony, szybko doszedł do wniosku, że manewr ten może powtórzyć i w innych lokalach. "Gangsterzy i filantropi" to debiut fabularny Jerzego Hoffmana i Edwarda Skórzewskiego, którzy dotąd znani byli jako para dokumentalistów. Wiele z ich filmów np. "Karuzela łowicka", "Typy na dziś", "Dwa oblicza Boga", odniosło sukcesy na międzynarodowych festiwalach. Ich wieloletnie doświadczenia w "zapisywaniu" rzeczywistości widoczne są także w "Gangsterach i filantropach"."
generate(input_text)
# Out:
#   File "<ipython-input-10-985197466612>", line 1
#     input_text = "Personel, sądząc iż Kowalski jest kontrolerem PIH - u, momentalnie zmienił swój stosunek do klientów, bohater znalazł w swojej gazecie banknot pięćsetzłotowy. Początkowo zaskoczony, szybko doszedł do wniosku, że manewr ten może powtórzyć i w innych lokalach. "Gangsterzy i filantropi" to debiut fabularny Jerzego Hoffmana i Edwarda Skórzewskiego, którzy dotąd znani byli jako para dokumentalistów. Wiele z ich filmów np. "Karuzela łowicka", "Typy na dziś", "Dwa oblicza Boga", odniosło sukcesy na międzynarodowych festiwalach. Ich wieloletnie doświadczenia w "zapisywaniu" rzeczywistości widoczne są także w "Gangsterach i filantropach"."
#                                                                                                                                                                                                                                                                                       ^
# ...

# %%
input_text = "Do you want to use a natural language model comparable to GPT-3 for free?"

generate(input_text)
# Out:
# 'no'

# %%
input_text = "what is most beatiful city in Poland ?"

generate(input_text)
# Out:
# 'Warsaw'
